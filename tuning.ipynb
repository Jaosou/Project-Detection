# %%
# !pip install numpy opencv-python tqdm matplotlib
# Out:
# Requirement already satisfied: numpy in c:\project\end\code\new\tf-env\lib\site-packages (1.26.4)
# Collecting opencv-python
#   Using cached opencv_python-4.12.0.88-cp37-abi3-win_amd64.whl (39.0 MB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.6-cp311-cp311-win_amd64.whl (8.1 MB)
# Collecting numpy
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Requirement already satisfied: colorama in c:\project\end\code\new\tf-env\lib\site-packages (from tqdm) (0.4.6)
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#      -------------------------------------- 225.2/225.2 kB 2.0 MB/s eta 0:00:00
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.60.1-cp311-cp311-win_amd64.whl (2.3 MB)
#      ---------------------------------------- 2.3/2.3 MB 2.0 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1
#   Downloading kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
#      ---------------------------------------- 73.8/73.8 kB ? eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\project\end\code\new\tf-env\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8
#   Downloading pillow-11.3.0-cp311-cp311-win_amd64.whl (7.0 MB)
#      ---------------------------------------- 7.0/7.0 MB 3.3 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
#      -------------------------------------- 113.9/113.9 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.7 in c:\project\end\code\new\tf-env\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\project\end\code\new\tf-env\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: tqdm, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, opencv-python, contourpy, matplotlib
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Project\\End\\Code\\New\\tf-env\\Lib\\site-packages\\~umpy.libs\\libopenblas64__v0.3.23-293-gc2f4bdbb-gcc_10_3_0-2bde3a66a51006b2b53eb373ff767a3f.dll'
# Check the permissions.
#
#
# [notice] A new release of pip available: 22.3 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import cv2
from os import listdir
from os.path import isfile, join
from tqdm import tqdm
import tensorflow as tf 
# from keras.models import Sequential , load_model
# from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
# from keras.applications import MobileNetV2
# from keras.callbacks import EarlyStopping
# import matplotlib.pyplot as plt
# from tensorflow.keras.preprocessing.image import ImageDataGenerator
# print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# print(tf.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import numpy as np
# ----> 2 import cv2
#       3 from os import listdir
#       4 from os.path import isfile, join
#
# ModuleNotFoundError: No module named 'cv2'
